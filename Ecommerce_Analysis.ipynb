# %% [markdown]
# <a href="https://colab.research.google.com/github/alam292/ecommerce-sales-performance-customer-behavior-analysis/blob/main/Ecommerce_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Data Collection

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-05dc5aa3-1cdb-4a35-a682-55c633276e59" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05dc5aa3-1cdb-4a35-a682-55c633276e59">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("orders.csv")

# %%
df
# Out:
#            order_id customer_id   product_id  seller_id  \
# 0       ORD00000001  CUST030578  PROD0006320  SELL01114
# 1       ORD00000002  CUST008134  PROD0006694  SELL00275
# 2       ORD00000003  CUST018918  PROD0007508  SELL00674
# 3       ORD00000004  CUST019490  PROD0001008  SELL00423
# 4       ORD00000005  CUST009380  PROD0005506  SELL01230
# ...             ...         ...          ...        ...
# 379495  ORD00379496  CUST031314  PROD0002966  SELL01536
# 379496  ORD00379497  CUST017554  PROD0000052  SELL00877
# 379497  ORD00379498  CUST004270  PROD0005308  SELL00104
# 379498  ORD00379499  CUST014634  PROD0004705  SELL00968
# 379499  ORD00379500  CUST018208  PROD0000765  SELL00764
#
#                         order_date order_status  quantity  unit_price  \
# 0       2026-01-03 11:53:24.443541    delivered         3     6119.38
# 1       2026-01-03 11:54:24.443541    DELIVERED         8     1091.73
# 2       2026-01-03 11:55:24.443541    Delivered         9     2241.77
# ...

# %% [markdown]
# ##Data Understanding

# %%
df.head()
# Out:
#       order_id customer_id   product_id  seller_id  \
# 0  ORD00000001  CUST030578  PROD0006320  SELL01114
# 1  ORD00000002  CUST008134  PROD0006694  SELL00275
# 2  ORD00000003  CUST018918  PROD0007508  SELL00674
# 3  ORD00000004  CUST019490  PROD0001008  SELL00423
# 4  ORD00000005  CUST009380  PROD0005506  SELL01230
#
#                    order_date order_status  quantity  unit_price  discount  \
# 0  2026-01-03 11:53:24.443541    delivered         3     6119.38     44.14
# 1  2026-01-03 11:54:24.443541    DELIVERED         8     1091.73     17.08
# 2  2026-01-03 11:55:24.443541    Delivered         9     2241.77     49.01
# 3  2026-01-03 11:56:24.443541      shipped         5     2509.03      5.25
# 4  2026-01-03 11:57:24.443541    delivered         6     8852.91     46.81
#
#    tax_amount  shipping_fee  total_amount   payment_id payment_method  \
# 0     1162.17        197.02      24035.61  PAY00120243            COD
# ...

# %%
df.tail()
# Out:
#            order_id customer_id   product_id  seller_id  \
# 379495  ORD00379496  CUST031314  PROD0002966  SELL01536
# 379496  ORD00379497  CUST017554  PROD0000052  SELL00877
# 379497  ORD00379498  CUST004270  PROD0005308  SELL00104
# 379498  ORD00379499  CUST014634  PROD0004705  SELL00968
# 379499  ORD00379500  CUST018208  PROD0000765  SELL00764
#
#                         order_date order_status  quantity  unit_price  \
# 379495  2026-04-02 12:20:24.443541      SHIPPED         1     6586.41
# 379496  2026-01-26 08:36:24.443541      shipped        10     2053.86
# 379497  2026-02-23 02:42:24.443541    Delivered         7     2215.84
# 379498                         NaN      SHIPPED         1      307.62
# 379499  2026-09-06 14:27:24.443541      Shipped         5     1818.64
#
#         discount  tax_amount  shipping_fee  total_amount   payment_id  \
# 379495     12.60     1460.93        486.94      47030.87  PAY00227888
# ...

# %%
df.shape
# Out:
# (379500, 20)

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'seller_id', 'order_date',
#        'order_status', 'quantity', 'unit_price', 'discount', 'tax_amount',
#        'shipping_fee', 'total_amount', 'payment_id', 'payment_method',
#        'payment_status', 'shipping_city', 'shipping_state', 'shipping_pincode',
#        'delivery_date', 'customer_rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379500 entries, 0 to 379499
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          379500 non-null  object
#  1   customer_id       379500 non-null  object
#  2   product_id        379500 non-null  object
#  3   seller_id         379500 non-null  object
#  4   order_date        368117 non-null  object
#  5   order_status      379500 non-null  object
#  6   quantity          379500 non-null  int64
#  7   unit_price        379500 non-null  float64
#  8   discount          379500 non-null  float64
#  9   tax_amount        379500 non-null  float64
#  10  shipping_fee      379500 non-null  float64
#  11  total_amount      379500 non-null  float64
#  12  payment_id        379500 non-null  object
#  13  payment_method    331919 non-null  object
#  14  payment_status    379500 non-null  object
# ...

# %%
df.describe()
# Out:
#             quantity     unit_price       discount     tax_amount  \
# count  379500.000000  379500.000000  379500.000000  379500.000000
# mean       72.647049   14929.479919      26.498286    1001.656230
# std       817.079087   98952.862262      23.371946     577.319061
# min        -5.000000    -100.000000     -50.000000       0.010000
# 25%         3.000000    2524.580000      12.420000     501.327500
# 50%         5.000000    5053.405000      25.150000    1004.925000
# 75%         8.000000    7570.042500      37.920000    1501.660000
# max      9999.000000  999999.000000     200.000000    1999.980000
#
#         shipping_fee   total_amount  shipping_pincode  customer_rating
# count  379500.000000  379500.000000     368244.000000    317666.000000
# mean      249.739616   25079.195357     549918.581370         3.065525
# std       144.500792   14412.345027     260052.677007         1.563897
# min         0.000000     100.140000     100003.000000         0.000000
# ...

# %%
df.describe(include = "object")
# Out:
#            order_id customer_id   product_id  seller_id  \
# count        379500      379500       379500     379500
# unique       372106       38375         7650       1537
# top     ORD00192207  CUST006550  PROD0005664  SELL00071
# freq              4          35          122        532
#
#                         order_date order_status   payment_id payment_method  \
# count                       368117       379500       379500         331919
# unique                      365933           10       264730              7
# top     2026-05-07 01:06:24.443541    Cancelled  PAY00010828         Wallet
# freq                             2        38225            8          47571
#
#        payment_status shipping_city shipping_state               delivery_date
# count          379500        379500         379500                      379281
# unique              4            20             16                      377031
# ...

# %%
df.isnull().sum()
# Out:
# order_id                0
# customer_id             0
# product_id              0
# seller_id               0
# order_date          11383
# order_status            0
# quantity                0
# unit_price              0
# discount                0
# tax_amount              0
# shipping_fee            0
# total_amount            0
# payment_id              0
# payment_method      47581
# payment_status          0
# shipping_city           0
# shipping_state          0
# shipping_pincode    11256
# delivery_date         219
# customer_rating     61834
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# order_id            372106
# customer_id          38375
# product_id            7650
# seller_id             1537
# order_date          365933
# order_status            10
# quantity                13
# unit_price          308361
# discount              5004
# tax_amount          169687
# shipping_fee         49972
# total_amount        363159
# payment_id          264730
# payment_method           7
# payment_status           4
# shipping_city           20
# shipping_state          16
# shipping_pincode    300823
# delivery_date       377031
# customer_rating          9
# dtype: int64

# %%
df["shipping_city"].unique()
# Out:
# array(['Pune', 'Noida', 'Lucknow', 'Indore', 'Vadodara', 'Bengaluru',
#        'Bhopal', 'Nagpur', 'Kochi', 'Mumbai', 'Jaipur', 'Hyderabad',
#        'Visakhapatnam', 'Chennai', 'Kolkata', 'Ahmedabad', 'Delhi',
#        'Patna', 'Chandigarh', 'Surat'], dtype=object)

# %%
df.dtypes
# Out:
# order_id             object
# customer_id          object
# product_id           object
# seller_id            object
# order_date           object
# order_status         object
# quantity              int64
# unit_price          float64
# discount            float64
# tax_amount          float64
# shipping_fee        float64
# total_amount        float64
# payment_id           object
# payment_method       object
# payment_status       object
# shipping_city        object
# shipping_state       object
# shipping_pincode    float64
# delivery_date        object
# customer_rating     float64
# dtype: object

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# missing value

# %%
df.isnull().sum()
# Out:
# order_id                0
# customer_id             0
# product_id              0
# seller_id               0
# order_date          11383
# order_status            0
# quantity                0
# unit_price              0
# discount                0
# tax_amount              0
# shipping_fee            0
# total_amount            0
# payment_id              0
# payment_method      47581
# payment_status          0
# shipping_city           0
# shipping_state          0
# shipping_pincode    11256
# delivery_date         219
# customer_rating     61834
# dtype: int64
